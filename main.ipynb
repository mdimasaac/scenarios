# %%
import pandas as pd
df1 = pd.read_excel("HR Data.xlsx")
df2 = pd.read_csv("food_wastage_data.csv")
df3 = pd.read_csv("LA crime - processed.csv")

# %%
print(df1.shape)
display(df1.head())

print(df2.shape)
display(df2.head())

print(df3.shape)
display(df3.head())
# Out:
# (1470, 39)
#   Attrition    Business Travel CF_age band CF_attrition label Department  \
# 0       Yes      Travel_Rarely     35 - 44       Ex-Employees      Sales
# 1        No  Travel_Frequently     45 - 54  Current Employees        R&D
# 2       Yes      Travel_Rarely     35 - 44       Ex-Employees        R&D
# 3        No  Travel_Frequently     25 - 34  Current Employees        R&D
# 4        No      Travel_Rarely     25 - 34  Current Employees        R&D
#
#   Education Field   emp no  Employee Number  Gender               Job Role  \
# 0   Life Sciences  STAFF-1                1  Female        Sales Executive
# 1   Life Sciences  STAFF-2                2    Male     Research Scientist
# 2           Other  STAFF-4                4    Male  Laboratory Technician
# 3   Life Sciences  STAFF-5                5  Female     Research Scientist
# 4         Medical  STAFF-7                7    Male  Laboratory Technician
#
# ...

# %%
df3 = df3.sample(n = 1500)
print(df3.shape)
display(df3.head())
# Out:
# (1500, 20)
#        date_reported    date_occ  area_name  \
# 27233     2021-02-21  2021-02-16    Olympic
# 341437    2022-07-29  2022-07-29    Mission
# 138327    2021-09-08  2021-09-08    West LA
# 198261    2021-12-16  2021-12-03     Harbor
# 256910    2022-03-22  2022-03-22  Southwest
#
#                           crime_cd_description  victim_age victim_sex  \
# 27233   criminal threats - no weapon displayed          27       male
# 341437                battery - simple assault          54       male
# 138327                battery - simple assault          43       male
# 198261                       theft of identity          51       male
# 256910  criminal threats - no weapon displayed          21     female
#
#                                   premis_description  \
# 27233                                       sidewalk
# 341437                                        street
# 138327                                other business
# ...

# %%
df3.dtypes
# Out:
# date_reported            object
# date_occ                 object
# area_name                object
# crime_cd_description     object
# victim_age                int64
# victim_sex               object
# premis_description       object
# weapon_description       object
# status_description       object
# location                 object
# lat                     float64
# lon                     float64
# time                     object
# daytime                  object
# day_occured              object
# day_reported             object
# report_delay             object
# report_delay_bin         object
# case                     object
# victim                   object
# dtype: object

# %%
df3["date_reported"] = pd.to_datetime(df3["date_reported"])

# %%
df3 = df3.sort_values(by ="date_reported")
display(df3.head())
# Out:
#     date_reported    date_occ  area_name  \
# 12     2021-01-01  2020-12-23   Wilshire
# 361    2021-01-01  2021-01-01   Foothill
# 701    2021-01-02  2021-01-02  Northeast
# 723    2021-01-02  2021-01-02     Newton
# 936    2021-01-03  2020-12-26  Southeast
#
#                                crime_cd_description  victim_age victim_sex  \
# 12                                theft of identity          44     female
# 361                               contempt of court          43     female
# 701  assault with deadly weapon, aggravated assault           0       male
# 723                                vehicle - stolen           0  no victim
# 936         letters, lewd  -  telephone calls, lewd          34     female
#
#                                premis_description weapon_description  \
# 12                                  other premise          no weapon
# 361  multi-unit dwelling (apartment, duplex, etc)          no weapon
# ...

# %%
display(df1.isna().sum())
display(df2.isna().sum())
display(df3.isna().sum())
# Out:
# Attrition                     0
# Business Travel               0
# CF_age band                   0
# CF_attrition label            0
# Department                    0
# Education Field               0
# emp no                        0
# Employee Number               0
# Gender                        0
# Job Role                      0
# Marital Status                0
# Over Time                     0
# Over18                        0
# Training Times Last Year      0
# Age                           0
# CF_current Employee           0
# Daily Rate                    0
# Distance From Home            0
# Education                     0
# Employee Count                0
# Environment Satisfaction      0
# Hourly Rate                   0
# Job Involvement               0
# Job Level                     0
# Job Satisfaction              0
# Monthly Income                0
# Monthly Rate                  0
# Num Companies Worked          0
# Percent Salary Hike           0
# ...

# %%
df3.to_csv("crime_data.csv", index = False)
df1.to_csv("employee_data.csv", index = False)

# %%
import pandas as pd
df4 = pd.read_csv("./amazon_data.csv")
print(df4.shape)
df4.head()
# Out:
# (11399, 20)
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x2318    COIMBRES13DEL01                  NaN                      NaN
# 1  0x3474     BANGRES15DEL01                 28.0                      4.6
# 2  0x9420      JAPRES09DEL03                 23.0                      4.5
# 3  0x72ee      JAPRES07DEL03                 21.0                      4.8
# 4  0xa759     CHENRES19DEL01                 31.0                      4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            11.003669             76.976494                   11.043669
# 1            12.975377             77.696664                   13.085377
# 2            26.911378             75.789034                   27.001378
# 3            26.766536             75.837333                   26.856536
# 4            12.986047             80.218114                   13.096047
#
# ...

# %%
df4 = df4.dropna()
display(df4.shape)
df4.isna().sum()
# Out:
# (10291, 20)
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weather                        0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Name:                          0
# dtype: int64

# %%
df4 = df4.sample(n = 1500)
print(df4.shape)
display(df4.head())
# Out:
# (1500, 20)
#           ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 5881  0x30b2      HYDRES02DEL02                 31.0                      4.6
# 9722  0x6085      MUMRES06DEL02                 36.0                      4.7
# 7831  0xb0d9   RANCHIRES19DEL02                 37.0                      4.8
# 7050  0x5928     PUNERES15DEL02                 25.0                      4.1
# 2753  0x3e68      HYDRES16DEL02                 28.0                      3.5
#
#       Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 5881            17.412330             78.449654                   17.462330
# 9722            19.055831             72.833984                   19.075831
# 7831            23.333017             85.317200                   23.413017
# 7050            18.636215             73.751081                   18.766215
# 2753            17.440827             78.393391                   17.460827
#
# ...

# %%
df4.to_csv("amazon_business_data.csv", index = False)
